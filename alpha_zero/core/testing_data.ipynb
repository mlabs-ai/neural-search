# %%
import os
import torch


os.environ['BOARD_SIZE'] = str(9)
from alpha_zero.core.eval_dataset import build_eval_dataset
from alpha_zero.utils.util import create_logger

# %%
print("BOARD_SIZE:", os.environ['BOARD_SIZE'])
# Out:
# BOARD_SIZE: 9

# %%
logger = create_logger('DEBUG')
eval_dataset = build_eval_dataset('./games/pro_games/9x9', num_stack=8, logger=logger)
# Out:
# INFO 2025-05-26 14:31:53 eval_dataset.py:247] Building evaluation dataset...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 logger = create_logger('DEBUG')
# ----> 2 eval_dataset = build_eval_dataset('./games/pro_games/go/9x9', num_stack=8, logger=logger)
#
# File ~/Developer/neural-search/alpha_zero/core/eval_dataset.py:266, in build_eval_dataset(games_dir, num_stack, logger)
#     263         target_pi.append(transition[1])
#     264         target_v.append(transition[2])
# --> 266 states = torch.from_numpy(np.stack(states, axis=0)).to(dtype=torch.float32)
#     267 target_pi = torch.from_numpy(np.stack(target_pi, axis=0)).to(dtype=torch.float32)
#     268 target_v = torch.from_numpy(np.stack(target_v, axis=0)).to(dtype=torch.float32)
#
# File ~/Developer/neural-search/.venv/lib/python3.12/site-packages/numpy/_core/shape_base.py:453, in stack(arrays, axis, out, dtype, casting)
#     451 arrays = [asanyarray(arr) for arr in arrays]
#     452 if not arrays:
# --> 453     raise ValueError('need at least one array to stack')
#     455 shapes = {arr.shape for arr in arrays}
#     456 if len(shapes) != 1:
#
# ValueError: need at least one array to stack

# %%
import torch
from torch.utils.data import DataLoader

# %%
try:
    torch.save(eval_dataset, 'go_dataset.pth')
    print("Dataset saved successfully!")
except Exception as e:
    print(f"Error saving dataset: {e}")

# %%
eval_dataset = torch.load('go_dataset.pth')

# %%
eval_dataset.__len__()

# %%
state, pi, v= eval_dataset.__getitem__(0)

# %%
state.shape, pi.shape, v.shape

# %%
dataloader = DataLoader(
            eval_dataset,
            batch_size=1024,
            pin_memory=True,
            shuffle=True,
            drop_last=True,
        )

# %%
device = torch.device('cpu')

# %%
for states, target_pi, target_v in dataloader:
        states = states.to(device=device, non_blocking=True)
        target_pi = target_pi.to(device=device, non_blocking=True)
        target_v = target_v.to(device=device, non_blocking=True)

# %%
for transition in dataloader:
    transitions = transition

# %%
state, pi, v = transitions

# %%
state.shape

# %%
eval_dataset

# %%
try:
    torch.save(eval_dataset, 'go_dataset.pth')
    print("Dataset saved successfully!")
except Exception as e:
    print(f"Error saving dataset: {e}")

# %%
states, probs, values = eval_dataset.__getitem__(0)

# %%
values

# %%
states.shape, probs.shape, values.shape
